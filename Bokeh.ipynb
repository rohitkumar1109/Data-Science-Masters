# %%
pip install bokeh

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.sampledata.iris import flowers

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file('test.html')

p = figure(title = 'Test flower')
p.xaxis.axis_label = 'petal_length'
p.yaxis.axis_label = 'petal_width'
p.circle(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div id="c038c506-0149-43c3-91e2-38a63da1ebc0" data-root-id="p1034" style="display: contents;"></div>

# %%
output_file('test.html')

p = figure(title = 'Test Flowers')
p.xaxis.axis_label = 'petal_length'
p.yaxis.axis_label = 'petal_width'
p.line(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div id="abdc9317-688a-497f-b860-4d01ea7afd16" data-root-id="p1081" style="display: contents;"></div>

# %%
x = [2,3,4,5,6,7]
y = [3,4,5,6,7,8]
output_file('line.html')

p = figure(title = 'Line Graph')
p.line(x,y)
show(p)
# Out:
#   <div id="cea8d19a-3355-439a-a049-53021b012bb6" data-root-id="p1214" style="display: contents;"></div>

# %%
x = [2,3,4,5,6,7]
y = [3,4,5,6,7,8]
output_file('line.html')

p = figure(title = 'Line Graph')
p.scatter(x,y, size=10 , fill_color='red', legend_label = 'These are my data point')
show(p)
# Out:
#   <div id="d663673b-078a-458c-85be-db6d7902be86" data-root-id="p1433" style="display: contents;"></div>
